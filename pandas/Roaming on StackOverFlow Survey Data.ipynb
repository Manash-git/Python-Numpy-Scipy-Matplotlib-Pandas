# %%
# print("Test")

# %%
import pandas as pd

# %%
# df = pd.read_csv("survey_results_public.csv")
df = pd.read_csv("survey_results_public.csv", index_col= 'Respondent')

# %%
df

# %%
df

# %%
df.shape

# %%
df.info()

# %%
df

# %%
pd.set_option("display.max_columns",50)

# %%
df

# %%
df.head()

# %%
df.head(15)

# %%
df.tail()

# %%
df_scheme= pd.read_csv("survey_results_schema.csv")

# %%
df_scheme

# %%
df['Hobbyist']

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq', 'CompTotal',
#        'ConvertedComp', 'Country', 'CurrencyDesc', 'CurrencySymbol',
#        'DatabaseDesireNextYear', 'DatabaseWorkedWith', 'DevType', 'EdLevel',
#        'Employment', 'Ethnicity', 'Gender', 'JobFactors', 'JobSat', 'JobSeek',
#        'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df['Hobbyist'].value_counts()

# %%
df.loc[0]

# %%
df.loc[0,'Hobbyist']

# %%
df.loc[0:5,['Hobbyist','Age']]

# %%
df.loc[0:10, 'Hobbyist' : 'CurrencyDesc']

# %%
high_slary_filter = (df['ConvertedComp']>300000)
df.loc[high_slary_filter]

# %%
df.loc[high_slary_filter,['Age','Age1stCode','YearsCode','Country']]
# Out:
#              Age            Age1stCode           YearsCode        Country
# Respondent
# 18          32.0                    12                  19  United States
# 57          44.0                    12                  33  United States
# 65          34.0                    13                  21  United States
# 69          25.0                    12                  13         France
# 123         26.0                    12                   8  United States
# ...          ...                   ...                 ...            ...
# 65341        NaN                    11                  17  United States
# 65381        NaN                     8                  30    Afghanistan
# 65456        NaN  Younger than 5 years  More than 50 years    Afghanistan
# 65502        NaN                    11                   5  United States
# 65527        NaN                    11                  14  United States
#
# [1620 rows x 4 columns]

# %%
slary_country_age = (df['ConvertedComp']>350000,'Country') 
df.loc[slary_country_age]
# Out:
# Respondent
# 18       United States
# 57       United States
# 65       United States
# 69              France
# 123      United States
#              ...
# 65341    United States
# 65381      Afghanistan
# 65456      Afghanistan
# 65502    United States
# 65527    United States
# Name: Country, Length: 1498, dtype: object

# %%
slary_country_age = (df['ConvertedComp']>350000,['Age','Country']) 
df.loc[slary_country_age]
# Out:
#              Age        Country
# Respondent
# 18          32.0  United States
# 57          44.0  United States
# 65          34.0  United States
# 69          25.0         France
# 123         26.0  United States
# ...          ...            ...
# 65341        NaN  United States
# 65381        NaN    Afghanistan
# 65456        NaN    Afghanistan
# 65502        NaN  United States
# 65527        NaN  United States
#
# [1498 rows x 2 columns]

# %%
country_list = ['United States',"India"]
check = df['Country'].isin(country_list)
df.loc[check]
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 5           I used to be a developer by profession, but no...      Yes  31.0
# 7                              I am a developer by profession      Yes   NaN
# 8                              I am a developer by profession      Yes  36.0
# 14                             I am a developer by profession      Yes  27.0
# 17                             I am a developer by profession      Yes  25.0
# ...                                                       ...      ...   ...
# 62464                                                     NaN      Yes   NaN
# 62954                                                     NaN      Yes   NaN
# 63077                                                     NaN      Yes   NaN
# 64236                                                     NaN      Yes   NaN
# 64858                                                     NaN      Yes   NaN
#
# ...

# %%
country_list = ['United States',"India"]
check = df['Country'].isin(country_list)
df.loc[check,['Age']]
# Out:
#              Age
# Respondent
# 5           31.0
# 7            NaN
# 8           36.0
# 14          27.0
# 17          25.0
# ...          ...
# 62464        NaN
# 62954        NaN
# 63077        NaN
# 64236        NaN
# 64858        NaN
#
# [20872 rows x 1 columns]

# %%
df.loc[check,['Age']].shape
# Out:
# (20872, 1)

# %%
df.loc[check].shape
# Out:
# (20872, 60)

# %%
df['LanguageWorkedWith']
# Out:
# Respondent
# 1                                   C#;HTML/CSS;JavaScript
# 2                                         JavaScript;Swift
# 3                                 Objective-C;Python;Swift
# 4                                                      NaN
# 5                                        HTML/CSS;Ruby;SQL
#                                ...
# 64858                                                  NaN
# 64867    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64898                                                  NaN
# 64925                                             HTML/CSS
# 65112                      C#;HTML/CSS;Java;JavaScript;SQL
# Name: LanguageWorkedWith, Length: 64461, dtype: object

# %%
lang_filt = df['LanguageWorkedWith'].str.contains('Python', na = False)
df.loc[lang_filt]
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 3                                 I code primarily as a hobby      Yes   NaN
# 8                              I am a developer by profession      Yes  36.0
# 10                             I am a developer by profession      Yes  22.0
# 13          I am not primarily a developer, but I write co...      Yes  53.0
# 15                     I am a student who is learning to code      Yes   NaN
# ...                                                       ...      ...   ...
# 61561                                                     NaN      Yes  64.0
# 62391                                                     NaN      Yes   NaN
# 63077                                                     NaN      Yes   NaN
# 63640                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
#
# ...

# %%
df.loc[lang_filt,'LanguageWorkedWith']
# Out:
# Respondent
# 3                                 Objective-C;Python;Swift
# 8                                               Python;SQL
# 10                     HTML/CSS;Java;JavaScript;Python;SQL
# 13                                     C;JavaScript;Python
# 15        Bash/Shell/PowerShell;C;HTML/CSS;Java;Python;SQL
#                                ...
# 61561    Bash/Shell/PowerShell;HTML/CSS;JavaScript;Perl...
# 62391       C++;HTML/CSS;JavaScript;Python;Ruby;TypeScript
# 63077              C++;HTML/CSS;Java;JavaScript;Python;SQL
# 63640    Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;J...
# 64867    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# Name: LanguageWorkedWith, Length: 25287, dtype: object

# %%
df.loc[lang_filt,'LanguageWorkedWith'].shape
# Out:
# (25287,)
