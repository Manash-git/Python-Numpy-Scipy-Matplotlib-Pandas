# %%
print("ok")
# Out:
# ok

# %%
import pandas as pd
# df = pd.read_csv("survey_results_public.csv")
df = pd.read_csv("survey_results_public.csv", index_col= 'Respondent')
#df.head()

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq', 'CompTotal',
#        'ConvertedComp', 'Country', 'CurrencyDesc', 'CurrencySymbol',
#        'DatabaseDesireNextYear', 'DatabaseWorkedWith', 'DevType', 'EdLevel',
#        'Employment', 'Ethnicity', 'Gender', 'JobFactors', 'JobSat', 'JobSeek',
#        'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df.rename(columns={
    'ConvertedComp' : 'Salary$'
})
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq', 'CompTotal',
#        'ConvertedComp', 'Country', 'CurrencyDesc', 'CurrencySymbol',
#        'DatabaseDesireNextYear', 'DatabaseWorkedWith', 'DevType', 'EdLevel',
#        'Employment', 'Ethnicity', 'Gender', 'JobFactors', 'JobSat', 'JobSeek',
#        'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df.rename(columns={
    'ConvertedComp' : 'Salary$'
},inplace=True)
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq', 'CompTotal',
#        'Salary$', 'Country', 'CurrencyDesc', 'CurrencySymbol',
#        'DatabaseDesireNextYear', 'DatabaseWorkedWith', 'DevType', 'EdLevel',
#        'Employment', 'Ethnicity', 'Gender', 'JobFactors', 'JobSat', 'JobSeek',
#        'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df.columns.value_counts()
# Out:
# PurchaseWhat                    1
# WelcomeChange                   1
# Age1stCode                      1
# SurveyEase                      1
# JobSeek                         1
# CurrencySymbol                  1
# NEWCollabToolsWorkedWith        1
# NEWPurpleLink                   1
# WorkWeekHrs                     1
# OrgSize                         1
# PlatformWorkedWith              1
# JobFactors                      1
# NEWCollabToolsDesireNextYear    1
# DevType                         1
# EdLevel                         1
# SOVisitFreq                     1
# Age                             1
# Trans                           1
# NEWOnboardGood                  1
# CompTotal                       1
# NEWDevOps                       1
# NEWEdImpt                       1
# Ethnicity                       1
# Salary$                         1
# NEWSOSites                      1
# Hobbyist                        1
# CurrencyDesc                    1
# ...

# %%
df['Salary$'].value_counts()
# Out:
# 120000.0     341
# 100000.0     306
# 150000.0     277
# 2000000.0    258
# 1000000.0    258
#             ...
# 102700.0       1
# 68721.0        1
# 96250.0        1
# 38456.0        1
# 21487.0        1
# Name: Salary$, Length: 6958, dtype: int64

# %%
df.sort_values(by=['Country','Salary$'], ascending=[True,False])
# Out:
#                                 MainBranch Hobbyist  Age  \
# Respondent
# 62788       I am a developer by profession      Yes  NaN
# 65381       I am a developer by profession       No  NaN
# 65456       I am a developer by profession      Yes  NaN
# 38672       I am a developer by profession       No  NaN
# 28374       I am a developer by profession      Yes  NaN
# ...                                    ...      ...  ...
# 60055                                  NaN       No  NaN
# 61121                                  NaN      Yes  NaN
# 61570                                  NaN       No  NaN
# 61918                                  NaN      Yes  NaN
# 62605                                  NaN       No  NaN
#
#                       Age1stCode CompFreq     CompTotal    Salary$  \
# Respondent
# 62788                        NaN   Weekly  8.000000e+06  1000000.0
# 65381                          8   Weekly  8.740000e+09  1000000.0
# ...

# %%
df['Salary$'].nlargest(10)
# Out:
# Respondent
# 123     2000000.0
# 125     2000000.0
# 193     2000000.0
# 665     2000000.0
# 699     2000000.0
# 724     2000000.0
# 818     2000000.0
# 986     2000000.0
# 1022    2000000.0
# 1036    2000000.0
# Name: Salary$, dtype: float64

# %%
df.nlargest(10,'Salary$')
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 123                            I am a developer by profession      Yes  26.0
# 125         I am not primarily a developer, but I write co...      Yes  41.0
# 193                            I am a developer by profession      Yes  29.0
# 665                            I am a developer by profession      Yes  24.0
# 699         I am not primarily a developer, but I write co...      Yes  39.0
# 724         I am not primarily a developer, but I write co...      Yes   NaN
# 818         I am not primarily a developer, but I write co...      Yes  40.0
# 986                            I am a developer by profession      Yes  27.0
# 1022                           I am a developer by profession      Yes  34.0
# 1036                           I am a developer by profession      Yes  26.0
#
#            Age1stCode CompFreq  CompTotal    Salary$        Country  \
# Respondent
# ...

# %%
df.nsmallest(10,'Salary$')
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 124                            I am a developer by profession       No  38.0
# 238         I am not primarily a developer, but I write co...      Yes   NaN
# 884                            I am a developer by profession      Yes  41.0
# 1116                           I am a developer by profession      Yes  25.0
# 1278                           I am a developer by profession      Yes  21.0
# 1794                           I am a developer by profession      Yes   NaN
# 2073                           I am a developer by profession      Yes  27.0
# 2196                           I am a developer by profession      Yes   NaN
# 2248                           I am a developer by profession       No   NaN
# 2323                           I am a developer by profession      Yes   NaN
#
#            Age1stCode CompFreq  CompTotal  Salary$              Country  \
# Respondent
# ...

# %%
df['Salary$'].median()
# Out:
# 54049.0

# %%
df.median()
# Out:
# Age               29.0
# CompTotal      63000.0
# Salary$        54049.0
# WorkWeekHrs       40.0
# dtype: float64

# %%
df.describe()
# Out:
#                 Age      CompTotal       Salary$   WorkWeekHrs
# count  45446.000000   3.482600e+04  3.475600e+04  41151.000000
# mean      30.834111  3.190464e+242  1.037561e+05     40.782174
# std        9.585392            inf  2.268853e+05     17.816383
# min        1.000000   0.000000e+00  0.000000e+00      1.000000
# 25%       24.000000   2.000000e+04  2.464800e+04     40.000000
# 50%       29.000000   6.300000e+04  5.404900e+04     40.000000
# 75%       35.000000   1.250000e+05  9.500000e+04     44.000000
# max      279.000000  1.111111e+247  2.000000e+06    475.000000

# %%
df['Salary$'].count()
# Out:
# 34756

# %%
df['Salary$'].value_counts()
# Out:
# 120000.0     341
# 100000.0     306
# 150000.0     277
# 2000000.0    258
# 1000000.0    258
#             ...
# 102700.0       1
# 68721.0        1
# 96250.0        1
# 38456.0        1
# 21487.0        1
# Name: Salary$, Length: 6958, dtype: int64

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
df['Hobbyist'].count()
# Out:
# 64416

# %%
df['SOAccount'].value_counts()
# Out:
# Yes                        47275
# No                          6101
# Not sure/can't remember     3429
# Name: SOAccount, dtype: int64

# %%
df['SOAccount']
# Out:
# Respondent
# 1         No
# 2        Yes
# 3        Yes
# 4        Yes
# 5        Yes
#         ...
# 64858    NaN
# 64867    NaN
# 64898    NaN
# 64925    NaN
# 65112    NaN
# Name: SOAccount, Length: 64461, dtype: object

# %%
df['SOAccount'].value_counts(normalize= True) *100
# Out:
# Yes                        83.223308
# No                         10.740252
# Not sure/can't remember     6.036440
# Name: SOAccount, dtype: float64

# %%
# make country group

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp

# %%
country_grp.get_group('India')
# Out:
#                                         MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 7                   I am a developer by profession      Yes   NaN         18
# 22                  I am a developer by profession      Yes   NaN         18
# 58                  I am a developer by profession      Yes   NaN         22
# 63          I am a student who is learning to code      Yes  21.0         17
# 149                 I am a developer by profession      Yes  36.0         31
# ...                                            ...      ...   ...        ...
# 54757                                          NaN      Yes   NaN         18
# 55407                                          NaN      Yes   NaN        NaN
# 62464                                          NaN      Yes   NaN        NaN
# 62954                                          NaN      Yes   NaN        NaN
# 64236                                          NaN      Yes   NaN        NaN
#
# ...

# %%
df_group= country_grp.get_group('India')
df_group.count()
# Out:
# MainBranch                      8384
# Hobbyist                        8403
# Age                             4413
# Age1stCode                      6912
# CompFreq                        4261
# CompTotal                       2681
# Salary$                         2668
# Country                         8403
# CurrencyDesc                    5135
# CurrencySymbol                  5135
# DatabaseDesireNextYear          5702
# DatabaseWorkedWith              6134
# DevType                         5625
# EdLevel                         6873
# Employment                      8323
# Ethnicity                       3539
# Gender                          5415
# JobFactors                      5461
# JobSat                          5051
# JobSeek                         6031
# LanguageDesireNextYear          6444
# LanguageWorkedWith              6884
# MiscTechDesireNextYear          5178
# MiscTechWorkedWith              4279
# NEWCollabToolsDesireNextYear    5360
# ...

# %%
filt = df['Country'] == 'United States'
df.loc[filt]
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 5           I used to be a developer by profession, but no...      Yes  31.0
# 8                              I am a developer by profession      Yes  36.0
# 14                             I am a developer by profession      Yes  27.0
# 17                             I am a developer by profession      Yes  25.0
# 18                             I am a developer by profession      Yes  32.0
# ...                                                       ...      ...   ...
# 58498                                                     NaN      Yes  32.0
# 58896                                                     NaN      Yes  29.0
# 60931                                                     NaN      Yes   NaN
# 63077                                                     NaN      Yes   NaN
# 64858                                                     NaN      Yes   NaN
#
# ...

# %%
df.loc[filt]['SOComm'].value_counts()
# Out:
# No, not really     3821
# Yes, somewhat      2805
# Neutral            2294
# No, not at all     1289
# Yes, definitely    1259
# Not sure             92
# Name: SOComm, dtype: int64

# %%
country_grp['Age'].value_counts().head(100)
# Out:
# Country      Age
# Afghanistan  23.0    5
#              22.0    3
#              25.0    3
#              15.0    2
#              20.0    2
#                     ..
# Argentina    49.0    1
#              50.0    1
#              56.0    1
#              58.0    1
#              61.0    1
# Name: Age, Length: 100, dtype: int64

# %%
country_grp['Age'].value_counts().loc['India']
# Out:
# Age
# 23.0    424
# 25.0    407
# 24.0    380
# 26.0    341
# 22.0    339
#        ...
# 69.0      1
# 70.0      1
# 73.0      1
# 94.0      1
# 98.0      1
# Name: Age, Length: 61, dtype: int64

# %%
country_grp['Age'].value_counts(normalize = True)
# Out:
# Country      Age
# Afghanistan  23.0    0.227273
#              22.0    0.136364
#              25.0    0.136364
#              15.0    0.090909
#              20.0    0.090909
#                        ...
# Zimbabwe     21.0    0.052632
#              25.0    0.052632
#              27.0    0.052632
#              30.0    0.052632
#              33.0    0.052632
# Name: Age, Length: 3697, dtype: float64

# %%
country_grp['Age'].value_counts(normalize = True).loc['China'] * 100
# Out:
# Age
# 27.0    8.426966
# 24.0    7.865169
# 22.0    7.303371
# 23.0    6.741573
# 25.0    6.179775
# 26.0    6.179775
# 29.0    5.617978
# 28.0    5.056180
# 21.0    4.494382
# 32.0    4.494382
# 20.0    3.932584
# 30.0    3.932584
# 31.0    3.932584
# 19.0    3.370787
# 35.0    3.370787
# 39.0    2.247191
# 37.0    1.685393
# 13.0    1.123596
# 16.0    1.123596
# 17.0    1.123596
# 18.0    1.123596
# 33.0    1.123596
# 34.0    1.123596
# 36.0    1.123596
# 38.0    1.123596
# 42.0    1.123596
# 51.0    1.123596
# 12.0    0.561798
# 14.0    0.561798
# 15.0    0.561798
# 40.0    0.561798
# 41.0    0.561798
# 43.0    0.561798
# 57.0    0.561798
# Name: Age, dtype: float64

# %%
country_grp['Salary$'].median().loc['Canada']
# Out:
# 68068.0

# %%
country_grp['Salary$'].agg(['median','mean']).loc['Canada']
# Out:
# median     68068.000000
# mean      115101.775465
# Name: Canada, dtype: float64

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq', 'CompTotal',
#        'Salary$', 'Country', 'CurrencyDesc', 'CurrencySymbol',
#        'DatabaseDesireNextYear', 'DatabaseWorkedWith', 'DevType', 'EdLevel',
#        'Employment', 'Ethnicity', 'Gender', 'JobFactors', 'JobSat', 'JobSeek',
#        'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
filt= df['Country']== 'Canada'

# %%
df.loc[filt]['LanguageWorkedWith']
# Out:
# Respondent
# 26                                       JavaScript;Python
# 32                               C;C++;Java;Python;SQL;VBA
# 51                        JavaScript;Python;SQL;TypeScript
# 66       Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;J...
# 75        Bash/Shell/PowerShell;HTML/CSS;JavaScript;Python
#                                ...
# 19609                                       C++;JavaScript
# 30010    Assembly;Bash/Shell/PowerShell;C;C++;Java;Java...
# 35616                                                  NaN
# 36174                           HTML/CSS;JavaScript;Python
# 62834                                        C;C#;C++;Java
# Name: LanguageWorkedWith, Length: 2191, dtype: object

# %%
df.loc[filt]['LanguageWorkedWith'].str.contains('Python')
# Out:
# Respondent
# 26        True
# 32        True
# 51        True
# 66        True
# 75        True
#          ...
# 19609    False
# 30010     True
# 35616      NaN
# 36174     True
# 62834    False
# Name: LanguageWorkedWith, Length: 2191, dtype: object

# %%
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 1011

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-51-e39436c4d4b6> in <module>
# ----> 1 country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())[filt]
#
# c:\users\crazy\appdata\local\programs\python\python38\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     906
#     907         if com.is_bool_indexer(key):
# --> 908             key = check_bool_indexer(self.index, key)
#     909
#     910         return self._get_with(key)
#
# c:\users\crazy\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexing.py in check_bool_indexer(index, key)
#    2315         mask = isna(result._values)
#    2316         if mask.any():
# -> 2317             raise IndexingError(
#    2318                 "Unalignable boolean Series provided as "
#    2319                 "indexer (index of the boolean Series and of "
#
# ...
